# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/NLPFinal/FLive"
# Out:
# /content/drive/MyDrive/Colab Notebooks/iNeuron/DL/Flive/NLP

# %%
try:
  from transformers import pipeline
except ModuleNotFoundError as not_found:
  print("installing...")
  # !pip install datasets transformers[sentencepiece] -q
  from transformers import pipeline
except Exception as e:
  raise e
# Out:
# installing...
#      |████████████████████████████████| 365 kB 4.1 MB/s
#      |████████████████████████████████| 4.7 MB 27.0 MB/s
#      |████████████████████████████████| 115 kB 99.3 MB/s
#      |████████████████████████████████| 141 kB 93.2 MB/s
#      |████████████████████████████████| 212 kB 97.9 MB/s
#      |████████████████████████████████| 101 kB 13.8 MB/s
#      |████████████████████████████████| 596 kB 87.9 MB/s
#      |████████████████████████████████| 127 kB 95.9 MB/s
#      |████████████████████████████████| 6.6 MB 78.4 MB/s
#      |████████████████████████████████| 1.3 MB 57.3 MB/s

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
classifier("I love my country")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998471736907959}]

# %%
classifier(["I love my country", "I didn't like the movie that I watched last night"])
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998471736907959},
#  {'label': 'NEGATIVE', 'score': 0.9922361969947815}]

# %%
classifier("Wayne Knight said it best three decades ago: We got Dodgson here, and nobody cares.")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.7722482681274414}]

# %%
review = """KGF is KANNADA's GOLD FILM
KFF part 2- Boisterous, loud and machismo type effect, taking Kannada movie to great heights.
Almost realistic barring few errors, the strong story line is displayed with bullet train speed, tight screenplay and stunning dialogues.
Key characters have been given equal weight and power- that's the best part."""

# %%
classifier(review)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998303651809692}]

# %%
classifier_zero_shot = pipeline("zero-shot-classification")
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision c626438 (https://huggingface.co/facebook/bart-large-mnli).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/1.13k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.52G [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
classifier_zero_shot(
    "This course is about artificial intelligence, Here we will learn theory and practical both.",
    candidate_labels=["politics", "business", "education"],
)
# Out:
# {'labels': ['education', 'business', 'politics'],
#  'scores': [0.49157828092575073, 0.39495179057121277, 0.11346995830535889],
#  'sequence': 'This course is about artificial intelligence, Here we will learn theory and practical both.'}

# %% [markdown]
# |||
# -|-
# pre-training | fine-tuning
# training from scratch | transfer learning

# %%
generator = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to gpt2 and revision 6c0e608 (https://huggingface.co/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
generator("This course is about artificial intelligence")[0]["generated_text"]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1207: UserWarning: Neither `max_length` nor `max_new_tokens` have been set, `max_length` will default to 50 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# 'This course is about artificial intelligence. It has a goal in mind: "a society in which intelligence, along with the pursuit of happiness and fulfillment, is no longer only an intellectual activity, but a social tool. It will be possible to develop a'

# %%
generator = pipeline("text-generation", model="distilgpt2")
# Out:
# Downloading config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/336M [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
generator("This course is about artificial intelligence",
          max_length=40,
          num_return_sequences=3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "This course is about artificial intelligence. We don't just start with a specific class and a particular task. Instead we create a very general set of tasks that all the components are interested in at the moment"},
#  {'generated_text': 'This course is about artificial intelligence. We․re excited for this course to help you in any way you can. _______________________________________|__|__|__|__|__|__|'},
#  {'generated_text': 'This course is about artificial intelligence and the problems that it addresses — and it\'s about to take out some serious issues with it."'}]

# %%
generator("The movie was horrible",
          max_length=40,
          num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'The movie was horrible. I think most of the time its not my fault, but when you’re really in the first place it’s good. The movie was really great not only'},
#  {'generated_text': 'The movie was horrible to have been watching for a few months, and I\u202am sure this movie is different to it, and I like the look of it. It\u202as a great'}]

# %%
generator("The movie was horrible",
          max_length=40,
          num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'The movie was horrible but it did make lots of difference for kids.”'},
#  {'generated_text': 'The movie was horrible and violent. The only person willing to get away with it was the actor who kept in touch.”'}]

# %%
generator("The movie was horrible",
          max_length=40,
          num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'The movie was horrible and this wasn\'t enough for the world at large...\n\n\n"We had no other options to change it for that reason. I was surprised that some people started putting the movie'},
#  {'generated_text': 'The movie was horrible and it made no sense.”\nIt didn”t matter where we got to, but it didn”t matter where we got to,” ”'}]

# %%
generator("The movie was horrible",
          max_length=40,
          num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'The movie was horrible. But even with this, it was the true story, a story that gave a lot of hope to those on the left.\nNow I have no illusions about what it may'},
#  {'generated_text': "The movie was horrible, and I loved the show, but I'm not sure if that movie will have a lasting impact here, but I do feel that the only thing I hope it does is to"}]

# %%
generator("<p> This is HTML </p>",
          max_length=40,
          num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': '<p> This is HTML </p> <?xml version="1.0" encoding="utf-8" encoding="utf-8"?></p> <html "> <head>'},
#  {'generated_text': '<p> This is HTML </p> <p></p> <p></p> <p></p> <p></p> <p></p> </table> <table class'}]

# %%
generator("SELECT * FROM TABLE",
          max_length=40,
          num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'SELECT * FROM TABLE * TABLE * = TABLE * = TABLE * = TABLE * = TABLE * = TABLE * = TABLE * = TABLE * = TABLE * = TABLE * = TABLE * = TABLE *'},
#  {'generated_text': 'SELECT * FROM TABLE ( "SELECT TABLE ( "SELECT TABLE ( "SELECT TABLE ( "SELECT TABLE ( "SELECT TABLE ( "SELECT TABLE ( "SELECT TABLE ( "SELECT TABLE ( "SELECT TABLE'}]

# %%
unamasking = pipeline("fill-mask")
# Out:
# No model was supplied, defaulted to distilroberta-base and revision ec58a5b (https://huggingface.co/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/316M [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
unamasking("This course is about <mask> intelligence", top_k=3)
# Out:
# [{'score': 0.3974643647670746,
#   'sequence': 'This course is about artificial intelligence',
#   'token': 7350,
#   'token_str': ' artificial'},
#  {'score': 0.04689708352088928,
#   'sequence': 'This course is about gathering intelligence',
#   'token': 5660,
#   'token_str': ' gathering'},
#  {'score': 0.03379300981760025,
#   'sequence': 'This course is about cyber intelligence',
#   'token': 5381,
#   'token_str': ' cyber'}]

# %%
NER = pipeline("ner", grouped_entities=True)
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision f2482bf (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.24G [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/208k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   "`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to"

# %%
NER("I am Sunny and I work in iNeuron Intelligence. I live in Bangalore.")
# Out:
# [{'end': 10,
#   'entity_group': 'PER',
#   'score': 0.99791485,
#   'start': 5,
#   'word': 'Sunny'},
#  {'end': 45,
#   'entity_group': 'ORG',
#   'score': 0.9977857,
#   'start': 25,
#   'word': 'iNeuron Intelligence'},
#  {'end': 66,
#   'entity_group': 'LOC',
#   'score': 0.9982457,
#   'start': 57,
#   'word': 'Bangalore'}]

# %%
QA = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/249M [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/208k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/426k [00:00<?, ?B/s]

# %%
QA(
    question="Wher do I work?",
    context="I am Sunny and I work in iNeuron Intelligence. I live in Bangalore."
)
# Out:
# {'answer': 'iNeuron Intelligence',
#  'end': 45,
#  'score': 0.9462348222732544,
#  'start': 25}

# %%
QA(
    question="How far is India from Srilanka?",
    context="India’s frontier, which is roughly one-third coastline, abuts six countries. It is bounded to the northwest by Pakistan, to the north by Nepal, China, and Bhutan; and to the east by Myanmar (Burma). Bangladesh to the east is surrounded by India to the north, east, and west. The island country of Sri Lanka is situated some 40 miles (65 km) off the southeast coast of India across the Palk Strait and Gulf of Mannar."
)
# Out:
# {'answer': '40 miles', 'end': 332, 'score': 0.7146969437599182, 'start': 324}

# %%
summarization = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading config.json:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading vocab.json:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading merges.txt:   0%|          | 0.00/446k [00:00<?, ?B/s]

# %% [markdown]
# Abstraction: It generates new text to summarize
# Extraction: It extract new text to summarize

# %%
in_text = """Gradio is an open-source Python library that is used to build machine learning and data science demos and web applications.
With Gradio, you can quickly create a beautiful user interface around your machine learning models or data science workflow and let people "try it out" by dragging-and-dropping in their own images, pasting text, recording their own voice, and interacting with your demo, all through the browser."""

print(in_text)
summarization(in_text, max_length=56)[0]["summary_text"]
# Out:
# Gradio is an open-source Python library that is used to build machine learning and data science demos and web applications.
# With Gradio, you can quickly create a beautiful user interface around your machine learning models or data science workflow and let people "try it out" by dragging-and-dropping in their own images, pasting text, recording their own voice, and interacting with your demo, all through the browser.
# ' Gradio is an open-source Python library that is used to build machine learning and data science demos and web applications . With Gradio, you can quickly create a beautiful user interface around your machine learning models or data science workflow and let people "try it out"'

# %%
translator = pipeline('translation', model="Helsinki-NLP/opus-mt-fr-en")

# %%
translator("je bois du lait")

# %%
translator("je vis en Inde")

# %%
translator = pipeline('translation', model="Helsinki-NLP/opus-mt-hi-en")

# %%
translator("मेरा निवास स्थान भारत है")

# %% [markdown]
# # Biasness and limitation of Transformer models

# %%
unamasking("This man works as a <mask>")
# Out:
# [{'score': 0.08593558520078659,
#   'sequence': 'This man works as a courier',
#   'token': 37171,
#   'token_str': ' courier'},
#  {'score': 0.08269808441400528,
#   'sequence': 'This man works as a translator',
#   'token': 28894,
#   'token_str': ' translator'},
#  {'score': 0.052251171320676804,
#   'sequence': 'This man works as a waiter',
#   'token': 38233,
#   'token_str': ' waiter'},
#  {'score': 0.0514572337269783,
#   'sequence': 'This man works as a consultant',
#   'token': 8298,
#   'token_str': ' consultant'},
#  {'score': 0.037423085421323776,
#   'sequence': 'This man works as a bartender',
#   'token': 33080,
#   'token_str': ' bartender'}]

# %%
unamasking("This woman works as a <mask>")
# Out:
# [{'score': 0.10744449496269226,
#   'sequence': 'This woman works as a waitress',
#   'token': 35698,
#   'token_str': ' waitress'},
#  {'score': 0.08696018159389496,
#   'sequence': 'This woman works as a translator',
#   'token': 28894,
#   'token_str': ' translator'},
#  {'score': 0.06901906430721283,
#   'sequence': 'This woman works as a nurse',
#   'token': 9008,
#   'token_str': ' nurse'},
#  {'score': 0.06353739649057388,
#   'sequence': 'This woman works as a prostitute',
#   'token': 36289,
#   'token_str': ' prostitute'},
#  {'score': 0.04852958396077156,
#   'sequence': 'This woman works as a bartender',
#   'token': 33080,
#   'token_str': ' bartender'}]

# %%
unamasking("This black man is ") # SERIOUS BIASNESS
# Out:
# [{'score': 0.08256722241640091,
#   'sequence': 'This black man is black',
#   'token': 909,
#   'token_str': ' black'},
#  {'score': 0.03745059296488762,
#   'sequence': 'This black man is dead',
#   'token': 1462,
#   'token_str': ' dead'},
#  {'score': 0.0283760167658329,
#   'sequence': 'This black man is autistic',
#   'token': 33329,
#   'token_str': ' autistic'},
#  {'score': 0.02260437421500683,
#   'sequence': 'This black man is missing',
#   'token': 1716,
#   'token_str': ' missing'},
#  {'score': 0.020637337118387222,
#   'sequence': 'This black man is dying',
#   'token': 8180,
#   'token_str': ' dying'}]

# %%
generated_text = generator("This black man is")[0]["generated_text"]
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.

# %%
classifier(generated_text)
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9855608344078064}]

# %%
classifier_zero_shot(
    generated_text,
    candidate_labels=["biased", "unbiased", "racist"],
)
# Out:
# {'labels': ['biased', 'racist', 'unbiased'],
#  'scores': [0.5145734548568726, 0.4818873405456543, 0.0035391778219491243],
#  'sequence': 'This black man is being taken as the victim of a hate crime and taken to prison for his murder.\n\n\n\n\nThe man was released before he was booked into the jail on Thursday morning for the murder of an 11-year-old'}
